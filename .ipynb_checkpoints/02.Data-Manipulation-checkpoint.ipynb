# %%
rm(list = ls() ) 

movies <- read.csv("moviesData.csv")

# %%
movies
# Out:
#     X   title                         title_type   genre
# 1    1  Filly Brown                   Feature Film Drama
# 2    2  The Dish                      Feature Film Drama
# 3    3  Waiting for Guffman           Feature Film Comedy
# 4    4  The Age of Innocence          Feature Film Drama
# 5    5  Malevolence                   Feature Film Horror
# 6    6  Old Partner                   Documentary  Documentary
# 7    7  Lady Jane                     Feature Film Drama
# 8    8  Mad Dog Time                  Feature Film Drama
# 9    9  Beauty Is Embarrassing        Documentary  Documentary
# 10  10  The Snowtown Murders          Feature Film Drama
# 11  11  Superman II                   Feature Film Action & Adventure
# 12  12  Leap of Faith                 Feature Film Drama
# 13  13  The Royal Tenenbaums          Feature Film Comedy
# 14  14  School for Scoundrels         Feature Film Comedy
# 15  15  Rhinestone                    Feature Film Comedy
# ...

# %%
library(dplyr)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %%
movieComedy<-filter(movies,genre=="Comedy")

# %%
movieComedy
# Out:
#    X   title                                   title_type   genre  runtime
# 1    3 Waiting for Guffman                     Feature Film Comedy  84
# 2   13 The Royal Tenenbaums                    Feature Film Comedy 110
# 3   14 School for Scoundrels                   Feature Film Comedy 100
# 4   15 Rhinestone                              Feature Film Comedy 111
# 5   26 Oh, God! You Devil                      Feature Film Comedy  97
# 6   41 The Guru                                Feature Film Comedy  94
# 7   43 The Dream Team                          Feature Film Comedy 113
# 8   58 Happy, Texas                            Feature Film Comedy  98
# 9   67 Waking Up in Reno                       Feature Film Comedy  91
# 10  69 Rock 'n' Roll High School               Feature Film Comedy  93
# 11  73 Major League: Back to the Minors        Feature Film Comedy 100
# 12  76 Strange Brew                            Feature Film Comedy  90
# ...

# %%
movieComedyDr<-filter(movies,genre=="Comedy"|genre=="Drama")
movieComedyDr
# Out:
#     X   title                             title_type   genre  runtime
# 1    1  Filly Brown                       Feature Film Drama   80
# 2    2  The Dish                          Feature Film Drama  101
# 3    3  Waiting for Guffman               Feature Film Comedy  84
# 4    4  The Age of Innocence              Feature Film Drama  139
# 5    7  Lady Jane                         Feature Film Drama  142
# 6    8  Mad Dog Time                      Feature Film Drama   93
# 7   10  The Snowtown Murders              Feature Film Drama  119
# 8   12  Leap of Faith                     Feature Film Drama  108
# 9   13  The Royal Tenenbaums              Feature Film Comedy 110
# 10  14  School for Scoundrels             Feature Film Comedy 100
# 11  15  Rhinestone                        Feature Film Comedy 111
# 12  16  Burn After Reading                Feature Film Drama   96
# 13  17  The Doors                         Feature Film Drama  140
# ...

# %%
movieComedyR<-filter(movies,genre=="Comedy"|mpaa_rating=="R")
movieComedyR
# Out:
#     X   title                         title_type   genre              runtime
# 1    1  Filly Brown                   Feature Film Drama               80
# 2    3  Waiting for Guffman           Feature Film Comedy              84
# 3    5  Malevolence                   Feature Film Horror              90
# 4    8  Mad Dog Time                  Feature Film Drama               93
# 5   13  The Royal Tenenbaums          Feature Film Comedy             110
# 6   14  School for Scoundrels         Feature Film Comedy             100
# 7   15  Rhinestone                    Feature Film Comedy             111
# 8   16  Burn After Reading            Feature Film Drama               96
# 9   17  The Doors                     Feature Film Drama              140
# 10  18  The Wood                      Feature Film Drama              106
# 11  19  Jason X                       Feature Film Horror              91
# 12  21  Fallen                        Feature Film Drama              124
# ...

# %%
movieComedyR<-arrange(movies,imdb_rating)
movieComedyR
# Out:
#     X   title                                                title_type
# 1   349 Disaster Movie                                       Feature Film
# 2   325 Epic Movie                                           Feature Film
# 3   176 Battlefield Earth                                    Feature Film
# 4    46 Viva Knievel!                                        Feature Film
# 5   350 Teen Wolf Too                                        Feature Film
# 6   125 Jack and Jill                                        Feature Film
# 7   424 Carnosaur                                            Feature Film
# 8   443 Dumb and Dumberer: When Harry Met Lloyd              Feature Film
# 9   462 Galaxina                                             Feature Film
# 10  115 The Room                                             Feature Film
# 11  118 Dirty Love                                           Feature Film
# 12  379 Dance Flick                                          Feature Film
# ...

# %%
movieR<-arrange(movies,desc(imdb_rating))
movieR
# Out:
#     X   title                                                title_type
# 1   329 The Godfather, Part II                               Feature Film
# 2    60 Promises                                             Documentary
# 3   356 Memento                                              Feature Film
# 4   437 The Prestige                                         Feature Film
# 5    36 Aliens                                               Feature Film
# 6   371 The Last Lions                                       Documentary
# 7   386 My Flesh and Blood                                   Documentary
# 8   555 Pete Seeger: The Power of Song                       Documentary
# 9   430 Good Will Hunting                                    Feature Film
# 10   79 Warrior                                              Feature Film
# 11  197 V for Vendetta                                       Feature Film
# 12  333 49 Up                                                Documentary
# ...

# %%
movieGIM<-arrange(movies,imdb_rating,genre)
movieGIM
# Out:
#     X   title                                                title_type
# 1   349 Disaster Movie                                       Feature Film
# 2   325 Epic Movie                                           Feature Film
# 3   176 Battlefield Earth                                    Feature Film
# 4    46 Viva Knievel!                                        Feature Film
# 5   350 Teen Wolf Too                                        Feature Film
# 6   125 Jack and Jill                                        Feature Film
# 7   443 Dumb and Dumberer: When Harry Met Lloyd              Feature Film
# 8   424 Carnosaur                                            Feature Film
# 9   462 Galaxina                                             Feature Film
# 10  379 Dance Flick                                          Feature Film
# 11  118 Dirty Love                                           Feature Film
# 12  115 The Room                                             Feature Film
# ...

# %%
movieS01<-select(movies,imdb_rating,genre)
movieS01
# Out:
#     imdb_rating genre
# 1   5.5         Drama
# 2   7.3         Drama
# 3   7.6         Comedy
# 4   7.2         Drama
# 5   5.1         Horror
# 6   7.8         Documentary
# 7   7.2         Drama
# 8   5.5         Drama
# 9   7.5         Documentary
# 10  6.6         Drama
# 11  6.8         Action & Adventure
# 12  6.0         Drama
# 13  7.6         Comedy
# 14  5.9         Comedy
# 15  3.6         Comedy
# 16  7.0         Drama
# 17  7.2         Drama
# 18  6.9         Drama
# 19  4.4         Horror
# 20  3.6         Drama
# 21  7.0         Drama
# 22  7.6         Documentary
# 23  6.2         Drama
# 24  6.2         Drama
# 25  7.6         Documentary
# 26  5.3         Comedy
# 27  7.1         Drama
# 28  5.6         Horror
# 29  7.1         Mystery & Suspense
# 30  7.7         Science Fiction & Fantasy
# ⋮   ⋮           ⋮
# 571 6.0         Drama
# 572 6.2         Drama
# 573 5.7         Action & Adventure
# 574 4.9         Comedy
# 575 7.3         Documentary
# ...

# %%
movieS01<-select(movies,title, starts_with('t'))
movieS01
# Out:
#     title                         title_type   thtr_rel_year thtr_rel_month
# 1   Filly Brown                   Feature Film 2013           4
# 2   The Dish                      Feature Film 2001           3
# 3   Waiting for Guffman           Feature Film 1996           8
# 4   The Age of Innocence          Feature Film 1993          10
# 5   Malevolence                   Feature Film 2004           9
# 6   Old Partner                   Documentary  2009           1
# 7   Lady Jane                     Feature Film 1986           1
# 8   Mad Dog Time                  Feature Film 1996          11
# 9   Beauty Is Embarrassing        Documentary  2012           9
# 10  The Snowtown Murders          Feature Film 2012           3
# 11  Superman II                   Feature Film 1981           6
# 12  Leap of Faith                 Feature Film 1992          12
# 13  The Royal Tenenbaums          Feature Film 2002           1
# ...

# %%
movieS01<-select(movies,title, starts_with('t'))
movieS01
# Out:
#     title                         title_type   thtr_rel_year thtr_rel_month
# 1   Filly Brown                   Feature Film 2013           4
# 2   The Dish                      Feature Film 2001           3
# 3   Waiting for Guffman           Feature Film 1996           8
# 4   The Age of Innocence          Feature Film 1993          10
# 5   Malevolence                   Feature Film 2004           9
# 6   Old Partner                   Documentary  2009           1
# 7   Lady Jane                     Feature Film 1986           1
# 8   Mad Dog Time                  Feature Film 1996          11
# 9   Beauty Is Embarrassing        Documentary  2012           9
# 10  The Snowtown Murders          Feature Film 2012           3
# 11  Superman II                   Feature Film 1981           6
# 12  Leap of Faith                 Feature Film 1992          12
# 13  The Royal Tenenbaums          Feature Film 2002           1
# ...

# %%
s01<-summarize(movies,mean(imdb_rating))
s01
# Out:
#   mean(imdb_rating)
# 1 6.479333

# %%
s01<-group_by(movies,genre)
s01
# Out:
#     X   title                         title_type   genre
# 1    1  Filly Brown                   Feature Film Drama
# 2    2  The Dish                      Feature Film Drama
# 3    3  Waiting for Guffman           Feature Film Comedy
# 4    4  The Age of Innocence          Feature Film Drama
# 5    5  Malevolence                   Feature Film Horror
# 6    6  Old Partner                   Documentary  Documentary
# 7    7  Lady Jane                     Feature Film Drama
# 8    8  Mad Dog Time                  Feature Film Drama
# 9    9  Beauty Is Embarrassing        Documentary  Documentary
# 10  10  The Snowtown Murders          Feature Film Drama
# 11  11  Superman II                   Feature Film Action & Adventure
# 12  12  Leap of Faith                 Feature Film Drama
# 13  13  The Royal Tenenbaums          Feature Film Comedy
# 14  14  School for Scoundrels         Feature Film Comedy
# 15  15  Rhinestone                    Feature Film Comedy
# ...

# %%
s02<-summarize(s01,mean(imdb_rating))
s02
# Out:
# `summarise()` ungrouping output (override with `.groups` argument)
#   genre                     mean(imdb_rating)
# 1 Action & Adventure        5.970769
# 2 Comedy                    5.744828
# 3 Documentary               7.648077
# 4 Drama                     6.673443
# 5 Horror                    5.760870
# 6 Mystery & Suspense        6.479661
# 7 Science Fiction & Fantasy 5.755556
